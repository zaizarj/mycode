# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
#	32°47′04.0″N 117°7′22.2″W
# 40.2881° N, 76.6611° W
# Define coordinates of where to start our map
# 
# hershey = [40.284, -76.649]
# disney = [28.385, -81.563]
# boulder = [40.015, -105.2705]
# kansascity = [39.099, -94.578]

#start_location = [40.284, -76.649]
start_location = [3740.284, -76.649]

# Create the map
my_map = folium.Map(location = start_location,  # Latitude and Longitude of Map 
                    zoom_start = 13)            # Initial zoom level for the map (default is 10)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b72309617588637071a1f9aec758ddb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b72309617588637071a1f9aec758ddb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b72309617588637071a1f9aec758ddb1 = L.map(
#                 &quot;map_b72309617588637071a1f9aec758ddb1&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa783f3e367884183be8266c2ec6e473 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b72309617588637071a1f9aec758ddb1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Define the coordinates we want our markers to be at
hershey_hotel = [40.300, -76.659]     # famous hotel
hershey_park = [40.288, -76.654]   # family theme park
comics_and_paperback_plus = [40.179, -76.179]  # local comic shop


# Add markers to the map
# popup --> label for the Marker; click on the pins on the map!
folium.Marker(hershey_hotel, popup = 'Hershey Hotel').add_to(my_map)
folium.Marker(hershey_park, popup = 'Hershey Park').add_to(my_map)
folium.Marker(comics_and_paperback_plus, popup = 'Comics and Paperback Plus').add_to(my_map)

# change the icon on a marker (location of Hershey Factory)
# see more icons here: https://getbootstrap.com/docs/3.3/components/
folium.Marker([40.285, -76.650], popup = 'Hershey Factory', icon=folium.Icon(color="red", icon="info-sign")).add_to(my_map)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b72309617588637071a1f9aec758ddb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b72309617588637071a1f9aec758ddb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b72309617588637071a1f9aec758ddb1 = L.map(
#                 &quot;map_b72309617588637071a1f9aec758ddb1&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa783f3e367884183be8266c2ec6e473 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b72309617588637071a1f9aec758ddb1);
#
#
#             var marker_4878c6dbc9c37503887d7c779f09b326 = L.marker(
#                 [40.3, -76.659],
#                 {}
#             ).addTo(map_b72309617588637071a1f9aec758ddb1);
#
#
#         var popup_a411cdf603f47fe8abd71242fe87f04d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7df7b6fe6ab6feb5a6f5c5a9d34bd54e = $(`&lt;div id=&quot;html_7df7b6fe6ab6feb5a6f5c5a9d34bd54e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Hotel&lt;/div&gt;`)[0];
#                 popup_a411cdf603f47fe8abd71242fe87f04d.setContent(html_7df7b6fe6ab6feb5a6f5c5a9d34bd54e);
#
#
#
#         marker_4878c6dbc9c37503887d7c779f09b326.bindPopup(popup_a411cdf603f47fe8abd71242fe87f04d)
#         ;
#
#
#
#
#             var marker_b9735c497fe7cc3e40bb4ec6aa5449ea = L.marker(
#                 [40.288, -76.654],
#                 {}
#             ).addTo(map_b72309617588637071a1f9aec758ddb1);
#
#
#         var popup_0dea99007a137b5b153ccbe5cd43aa6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4723fe1e5384b8f8918e0de99971c32 = $(`&lt;div id=&quot;html_e4723fe1e5384b8f8918e0de99971c32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Park&lt;/div&gt;`)[0];
#                 popup_0dea99007a137b5b153ccbe5cd43aa6e.setContent(html_e4723fe1e5384b8f8918e0de99971c32);
#
#
#
#         marker_b9735c497fe7cc3e40bb4ec6aa5449ea.bindPopup(popup_0dea99007a137b5b153ccbe5cd43aa6e)
#         ;
#
#
#
#
#             var marker_e23fc3b7b414e8a3800d9bd6ac7c7d31 = L.marker(
#                 [40.179, -76.179],
#                 {}
#             ).addTo(map_b72309617588637071a1f9aec758ddb1);
#
#
#         var popup_f8cb88d616aa2cb6fc719aea127b2c29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28d70725df69f6789cdc7f95234904a7 = $(`&lt;div id=&quot;html_28d70725df69f6789cdc7f95234904a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Comics and Paperback Plus&lt;/div&gt;`)[0];
#                 popup_f8cb88d616aa2cb6fc719aea127b2c29.setContent(html_28d70725df69f6789cdc7f95234904a7);
#
#
#
#         marker_e23fc3b7b414e8a3800d9bd6ac7c7d31.bindPopup(popup_f8cb88d616aa2cb6fc719aea127b2c29)
#         ;
#
#
#
#
#             var marker_e5e3a78240fee352531bd8e894279407 = L.marker(
#                 [40.285, -76.65],
#                 {}
#             ).addTo(map_b72309617588637071a1f9aec758ddb1);
#
#
#             var icon_ff4b0e8d2f043d4a946093aa68c276bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e5e3a78240fee352531bd8e894279407.setIcon(icon_ff4b0e8d2f043d4a946093aa68c276bc);
#
#
#         var popup_f6cbbf66d04c22cef94f104d03686fa1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db5e9576a950ba1b32f46405e1284ce1 = $(`&lt;div id=&quot;html_db5e9576a950ba1b32f46405e1284ce1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Factory&lt;/div&gt;`)[0];
#                 popup_f6cbbf66d04c22cef94f104d03686fa1.setContent(html_db5e9576a950ba1b32f46405e1284ce1);
#
#
#
#         marker_e5e3a78240fee352531bd8e894279407.bindPopup(popup_f6cbbf66d04c22cef94f104d03686fa1)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_map.save("index.html")

# %%
# Using polygon markers with colors instead of default markers
polygon_map = folium.Map(location = start_location, zoom_start = 13)

# points of interest
hershey_hotel = [40.300, -76.659]     # famous hotel
hershey_park = [40.288, -76.654]   # family theme park
comics_and_paperback_plus = [40.179, -76.179]  # local comic shop


# Add markers to the map
folium.RegularPolygonMarker(hershey_hotel, popup = 'Hershey Hotel', fill_color = '#00ff40',
                            number_of_sides = 3, radius = 10).add_to(polygon_map)
folium.RegularPolygonMarker(hershey_park, popup = 'Hershey Park', fill_color = '#bf00ff',
                            number_of_sides = 5, radius = 10).add_to(polygon_map)
folium.RegularPolygonMarker(comics_and_paperback_plus, popup = 'Comics and Paperback Plus', fill_color = '#ff0000',
                           number_of_sides = 8, radius = 10).add_to(polygon_map)

#Display the map
polygon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab3c1cb9a335e57df9a820ed2afb95f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab3c1cb9a335e57df9a820ed2afb95f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab3c1cb9a335e57df9a820ed2afb95f2 = L.map(
#                 &quot;map_ab3c1cb9a335e57df9a820ed2afb95f2&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2137ddd9e12c9972995c86d8a5957b68 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab3c1cb9a335e57df9a820ed2afb95f2);
#
#
#             var regular_polygon_marker_7903ab1c1ba8afb3691734eb3882e83b = new L.RegularPolygonMarker(
#                 [40.3, -76.659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00ff40&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ab3c1cb9a335e57df9a820ed2afb95f2);
#
#
#         var popup_670c49aa1fb649dba64dd73204c3f707 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa2088dac0d2980d681d1ef5df41613b = $(`&lt;div id=&quot;html_aa2088dac0d2980d681d1ef5df41613b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Hotel&lt;/div&gt;`)[0];
#                 popup_670c49aa1fb649dba64dd73204c3f707.setContent(html_aa2088dac0d2980d681d1ef5df41613b);
#
#
#
#         regular_polygon_marker_7903ab1c1ba8afb3691734eb3882e83b.bindPopup(popup_670c49aa1fb649dba64dd73204c3f707)
#         ;
#
#
#
#
#             var regular_polygon_marker_8c6b31859822ac5312d4d29e08ca39f1 = new L.RegularPolygonMarker(
#                 [40.288, -76.654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#bf00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 5, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ab3c1cb9a335e57df9a820ed2afb95f2);
#
#
#         var popup_15360e5b2132d841a3f523195d6ed1e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43e7e5a463aa290df8db0959192caca1 = $(`&lt;div id=&quot;html_43e7e5a463aa290df8db0959192caca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Park&lt;/div&gt;`)[0];
#                 popup_15360e5b2132d841a3f523195d6ed1e3.setContent(html_43e7e5a463aa290df8db0959192caca1);
#
#
#
#         regular_polygon_marker_8c6b31859822ac5312d4d29e08ca39f1.bindPopup(popup_15360e5b2132d841a3f523195d6ed1e3)
#         ;
#
#
#
#
#             var regular_polygon_marker_b63eeb616922e5c7f1f9ffd517d78654 = new L.RegularPolygonMarker(
#                 [40.179, -76.179],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 8, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ab3c1cb9a335e57df9a820ed2afb95f2);
#
#
#         var popup_dd815e610481621fa5c1c17583581ef7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecf7b96daba3a42435fe722d65f078d0 = $(`&lt;div id=&quot;html_ecf7b96daba3a42435fe722d65f078d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Comics and Paperback Plus&lt;/div&gt;`)[0];
#                 popup_dd815e610481621fa5c1c17583581ef7.setContent(html_ecf7b96daba3a42435fe722d65f078d0);
#
#
#
#         regular_polygon_marker_b63eeb616922

# %%
#Adding a tileset to our map
map_with_tiles = folium.Map(location = start_location, tiles = 'Stamen Toner')
map_with_tiles
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69318d182f7e55da5b530d9bb5bb647e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69318d182f7e55da5b530d9bb5bb647e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69318d182f7e55da5b530d9bb5bb647e = L.map(
#                 &quot;map_69318d182f7e55da5b530d9bb5bb647e&quot;,
#                 {
#                     center: [40.284, -76.649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05e4d4b0b3274e9d709e71c55809650c = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_69318d182f7e55da5b530d9bb5bb647e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
circle_map = folium.Map(location=[40.288, -76.654], tiles="Stamen Toner", zoom_start=13)

folium.Circle(
    radius=100,
    location=[40.288, -76.654],
    popup="Hershey Park",
    color="crimson",
    fill=False,
).add_to(circle_map)

folium.CircleMarker(
    location=[40.179, -76.179],
    radius=50,
    popup="Palmyra",
    color="#3186cc",
    fill = False
    #fill=True,
    #fill_color="#3186cc"
).add_to(circle_map)

circle_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a7a19c0e90b849ed5a85f3bc4a288e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a7a19c0e90b849ed5a85f3bc4a288e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a7a19c0e90b849ed5a85f3bc4a288e8 = L.map(
#                 &quot;map_4a7a19c0e90b849ed5a85f3bc4a288e8&quot;,
#                 {
#                     center: [40.288, -76.654],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58dadb3bc08d027f0e5f3870a553b479 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a7a19c0e90b849ed5a85f3bc4a288e8);
#
#
#             var circle_55cc808134031148b1b5324c663642bf = L.circle(
#                 [40.288, -76.654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4a7a19c0e90b849ed5a85f3bc4a288e8);
#
#
#         var popup_02fe8ed87639e0d142f4ac18e4482cda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23f3c1bb87690bfb6845eb4925bf4dc7 = $(`&lt;div id=&quot;html_23f3c1bb87690bfb6845eb4925bf4dc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hershey Park&lt;/div&gt;`)[0];
#                 popup_02fe8ed87639e0d142f4ac18e4482cda.setContent(html_23f3c1bb87690bfb6845eb4925bf4dc7);
#
#
#
#         circle_55cc808134031148b1b5324c663642bf.bindPopup(popup_02fe8ed87639e0d142f4ac18e4482cda)
#         ;
#
#
#
#
#             var circle_marker_7fb79121062d31548d011d52ac4b1a77 = L.circleMarker(
#                 [40.179, -76.179],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4a7a19c0e90b849ed5a85f3bc4a288e8);
#
#
#         var popup_98218d5ae57dc14db03ff35117482633 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce35e2f381a6909afad3b0634e5a5569 = $(`&lt;div id=&quot;html_ce35e2f381a6909afad3b0634e5a5569&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Palmyra&lt;/div&gt;`)[0];
#                 popup_98218d5ae57dc14db03ff35117482633.setContent(html_ce35e2f381a6909afad3b0634e5a5569);
#
#
#
#         circle_marker_7fb79121062d31548d011d52ac4b1a77.bindPopup(popup_98218d5ae57dc14db03ff35117482633)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json

import requests

url = (
    "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data"
)
vis1 = json.loads(requests.get(f"{url}/vis1.json").text)
vis2 = json.loads(requests.get(f"{url}/vis2.json").text)
vis3 = json.loads(requests.get(f"{url}/vis3.json").text)

# %%
my_map = folium.Map(location=[46.3014, -123.7390], zoom_start=7, tiles="Stamen Terrain")

folium.Marker(
    location=[47.3489, -124.708],
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(vis1, width=450, height=250)
    ),
).add_to(my_map)

# add_child --> add this object to the first map and store it for the next one
# Vega --> a chart element similar to matplotlib
folium.Marker(
    location=[44.639, -124.5339],
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(vis2, width=450, height=250)
    ),
).add_to(my_map)

folium.Marker(
    location=[46.216, -124.1280],
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(vis3, width=450, height=250)
    ),
).add_to(my_map)

my_map

# %%
# python3 -m pip install pandas
import pandas as pd
# python3 -m pip install folium
import folium
# notice that we DO NOT need to include a requests package
# even though our data is made available by HTTP

# describe where our data is at
url = "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data" # base url
state_geo = f"{url}/us-states.json" # geoJSON data
state_unemployment = f"{url}/US_Unemployment_Oct2012.csv" # unemployment stats per state

# create a pandas dataframe
state_data = pd.read_csv(state_unemployment)  # umemployment stat per state

# show a map of the US with standard tileset
choropleth_map = folium.Map(location=[48, -102], zoom_start=3)

# create the layer we want to put on top of our base map
folium.Choropleth(
    geo_data=state_geo, #  URL, file path, or data object containing GeoJSON
    name="choropleth",  # The name of the layer, as it will appear in LayerControls
    data=state_data,    # Data to bind to the GeoJSON
    columns=["State", "Unemployment"], # used if data is from Pandas; these are the columns
    key_on="feature.id", # geo_data GeoJSON variable to bind to; must start with "feature"
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Unemployment Rate (%)", # Title for data legend
).add_to(choropleth_map)

# Creates a LayerControl object to be added on a folium map
folium.LayerControl().add_to(choropleth_map)

# display the map
choropleth_map

# %%
# modify the upper right legend (bins indicator)
bins = list(state_data["Unemployment"].quantile([0, 0.25, 0.5, 0.75, 1]))
                                      # Compute the q-th quantile of the data along the specified axis.
                                      
custom_bins_map = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    data=state_data,
    columns=["State", "Unemployment"],
    key_on="feature.id",
    fill_color="BuPu",
    fill_opacity=0.7,
    line_opacity=0.5,
    legend_name="Unemployment Rate (%)",
    bins=bins,
    reset=True,
).add_to(custom_bins_map)

custom_bins_map

# %%
import branca

url = (
    "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data"
)
county_data = f"{url}/us_county_data.csv"
county_geo = f"{url}/us_counties_20m_topo.json"


                              # any missing data will be replaced with an empty string
df = pd.read_csv(county_data, na_values=[" "])

                   # colormap --> branca submodule for dealing with colormaps
                   # colormap.linear --> makes a ColorMap from linear interpolation of a set of colors over a given index.
colorscale = branca.colormap.linear.YlOrRd_09.scale(0, 50e3)

employed_series = df.set_index("FIPS_Code")["Employed_2011"]


# style function to control map output
def style_function(feature):
    employed = employed_series.get(int(feature["id"][-5:]), None)
    return {
        "fillOpacity": 0.5,
        "weight": 0,
        "fillColor": "#black" if employed is None else colorscale(employed),
    }

# create the map object
styling_map = folium.Map(location=[48, -102], tiles="cartodbpositron", zoom_start=3)

folium.TopoJson(
    json.loads(requests.get(county_geo).text),
    "objects.us_counties_20m",
    style_function=style_function,
).add_to(styling_map)


styling_map

# %%
colorscale = branca.colormap.linear.YlGnBu_09.scale(0, 30)

employed_series = df.set_index("FIPS_Code")["Unemployment_rate_2011"]


def style_function(feature):
    employed = employed_series.get(int(feature["id"][-5:]), None)
    return {
        "fillOpacity": 0.5,
        "weight": 0,
        "fillColor": "#black" if employed is None else colorscale(employed),
    }


m = folium.Map(location=[48, -102], tiles="cartodbpositron", zoom_start=3)

# Creates a TopoJson object for plotting into a Map.
folium.TopoJson(
    json.loads(requests.get(county_geo).text), # TopoJSON data being plitted
    "objects.us_counties_20m", # The path of the desired object into the TopoJson structure
    style_function=style_function, # mapping a TopoJson geometry to a style dict
).add_to(m)


m
